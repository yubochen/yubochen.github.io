# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "inproceeding": {
        "file" : "output.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    },
    "article":{
        "file": "output.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2406-12416: " Beyond Under-Alignment: Atomic ... "
# SUCESSFULLY PARSED DBLP:conf/coling/ZhangC0LZSZ24: " Continual Few-shot Event Detection via Hierarchical Augmenta ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2403-17733: " Continual Few-shot Event Detec ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-18154: " Cutting Off the Head Ends the  ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-09911: " Enhancing Large Language Model ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-18344: " Focus on Your Question! Interp ... "
# SUCESSFULLY PARSED DBLP:conf/aaai/ChenCCLZ24: " Journey to the Center of the Knowledge Neurons: Discoveries  ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2405-14117: " Knowledge Localization: Missio ... "
# SUCESSFULLY PARSED DBLP:conf/coling/WangCL00JXLZ24: " Leros: Learning Explicit Reasoning on Synthesized Data for C ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2406-11566: " {MEMLA:} Enhancing Multilingua ... "
# SUCESSFULLY PARSED DBLP:conf/coling/Guo000024: " NutFrame: Frame-based Conceptual Structure Induction with LL ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2406-10890: " {RWKU:} Benchmarking Real-Worl ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2403-02959: " SimuCourt: Building Judicial D ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-13731: " The Da Vinci Code of Large Pre ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2405-18915: " Towards Faithful Chain-of-Thou ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-14409: " Tug-of-War Between Knowledge:  ... "
# SUCESSFULLY PARSED DBLP:conf/coling/JinC0LJXLZ24: " Tug-of-War between Knowledge: Exploring and Resolving Knowle ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2406-16033: " Unlocking the Future: Explorin ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-19103: " Whispers that Shake Foundation ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2402-10987: " WilKE: Wise-Layer Knowledge Ed ... "
# SUCESSFULLY PARSED DBLP:conf/coling/HeCJ00ZS024: " Zero-Shot Cross-Lingual Document-Level Event Causality Ident ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2403-02893: " Zero-Shot Cross-Lingual Docume ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/JinCH00023: " Alignment Precedes Fusion: Open-Vocabulary Named Entity Reco ... "
# WARNING Missing Expected Field 'author' from entry DBLP:conf/cncl/2023: " Chinese Computational Linguist ... "
# SUCESSFULLY PARSED DBLP:conf/semweb/WangGHX0LZ23: " CogNet2: {A} Multi-Level Frame Organized Knowledge Base Inte ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/HaoC0LXLJZ23: " Complex Event Schema Induction with Knowledge-Enriched Diffu ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/CaoH0LXLJZ23: " Event Ontology Completion with Hierarchical Structure Evolut ... "
# SUCESSFULLY PARSED DBLP:conf/aaai/Zhou00023: " Event Process Typing via Hierarchical Optimal Transport  "
# SUCESSFULLY PARSED DBLP:conf/acl/GuoW0LLZ23: " EventOA: An Event Ontology Alignment Benchmark Based on Fram ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/JinC0LZ23: " InstructoR: Instructing Unsupervised Conversational Dense Re ... "
# WARNING Missing Expected Field 'booktitle' from entry sui2023joint: " Joint entity and relation extr ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2308-13198: " Journey to the Center of the K ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/HeC0LLSZ23: " {LEGO:} {A} Multi-agent Collaborative Framework with Role-pl ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2311-12537: " Oasis: Data Curation and Asses ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2308-15851: " Prompting Vision Language Mode ... "
# SUCESSFULLY PARSED DBLP:conf/nlpcc/LiWCLZ23: " What Events Do Pre-trained Language Models Learn from Text?  ... "
# SUCESSFULLY PARSED DBLP:conf/aaai/CaoJ00023: " Zero-Shot Cross-Lingual Event Argument Extraction with Langu ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/ZhangXDCC0LLZ23: " ZhuJiu: {A} Multi-dimensional, Multi-faceted Chinese Benchma ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2308-14353: " ZhuJiu: {A} Multi-dimensional, ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/JinC00022: " A Good Neighbor, {A} Found Treasure: Mining Treasured Neighb ... "
# SUCESSFULLY PARSED DBLP:conf/coling/ZhouW000XJL22: " Augmentation, Retrieval, Generation: Event Sequence Predicti ... "
# SUCESSFULLY PARSED DBLP:conf/semeval/FuGLLS00022: " {CASIA} at SemEval-2022 Task 11: Chinese Named Entity Recogn ... "
# SUCESSFULLY PARSED DBLP:conf/coling/FuLYLG000L22: " CASIA@SMM4H'22: {A} Uniform Health Information Mining System ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/WangL00Z22: " CN-AutoMIC: Distilling Chinese Commonsense Knowledge from Pr ... "
# WARNING Missing Expected Field 'author' from entry DBLP:conf/cncl/2022: " Chinese Computational Linguist ... "
# SUCESSFULLY PARSED DBLP:conf/acl/JinMYHSWXCZ22: " CogKGE: {A} Knowledge Graph Embedding Toolkit and Benchmark  ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/JinMYZCCXLZ22: " CogKTR: {A} Knowledge-Enhanced Text Representation Toolkit f ... "
# SUCESSFULLY PARSED DBLP:conf/coling/HuangY000SZ22: " Document-Level Relation Extraction via Pair-Aware and Entity ... "
# SUCESSFULLY PARSED DBLP:conf/coling/Zhou000XJL22: " Generating Temporally-ordered Event Sequences via Event Opti ... "
# WARNING Missing Expected Field 'author' from entry DBLP:conf/ccks/2022: " Knowledge Graph and Semantic C ... "
# SUCESSFULLY PARSED DBLP:conf/acl/SuiT00020: " A Large-Scale Chinese Multimodal {NER} Dataset with Speech C ... "
# SUCESSFULLY PARSED DBLP:conf/acl/ZhouC000NCL20: " Automatic {ICD} Coding via Interactive Shared Representation ... "
# SUCESSFULLY PARSED zhou2021automatic: " Automatic ICD coding via interactive shared representation n ... "
# SUCESSFULLY PARSED DBLP:conf/smm4h/ZhouLGZCNWLZSCL21: " Classification, Extraction, and Normalization : CASIA{\_}Uni ... "
# SUCESSFULLY PARSED DBLP:conf/acl/JinCSWXZ21: " CogIE: An Information Extraction Toolkit for Bridging Texts  ... "
# SUCESSFULLY PARSED DBLP:conf/aaai/Wang0XZ021: " CogNet: Bridging Linguistic Knowledge, World Knowledge and C ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2103-02141: " CogNet: Bridging Linguistic Kn ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/ZhangLGCW0ZLS21: " CroAno : {A} Crowd Annotation Platform for Improving Label C ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/Sui00021: " Distantly Supervised Relation Extraction in Federated Settin ... "
# SUCESSFULLY PARSED DBLP:conf/acl/YangS000W20: " Document-level Event Extraction via Parallel Prediction Netw ... "
# SUCESSFULLY PARSED yang2021document: " Document-level event extraction via parallel prediction netw ... "
# SUCESSFULLY PARSED DBLP:conf/ccks/GanLZW0LZSL21: " Enhance Both Text and Label: Combination Strategies for Impr ... "
# SUCESSFULLY PARSED DBLP:conf/acl/ZuoCCLZPC21: " Improving Event Causality Identification via Self-Supervised ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2106-01654: " Improving Event Causality Iden ... "
# WARNING Missing Expected Field 'booktitle' from entry zuo2021improving: " Improving event causality iden ... "
# SUCESSFULLY PARSED DBLP:conf/nlpcc/GanLZWCLZSL21: " Incorporate Lexicon into Self-training: {A} Distantly Superv ... "
# SUCESSFULLY PARSED DBLP:conf/naacl/SuiCMQLZ21: " Knowledge Guided Metric Learning for Few-Shot Text Classific ... "
# SUCESSFULLY PARSED liu2021knowledge: " Knowledge enhanced event causality identification with menti ... "
# SUCESSFULLY PARSED DBLP:conf/acl/CaoZ000CP20: " Knowledge-Enriched Event Causality Identification via Latent ... "
# SUCESSFULLY PARSED cao2021knowledge: " Knowledge-enriched event causality identification via latent ... "
# SUCESSFULLY PARSED DBLP:conf/acl/ZuoC000PC20: " LearnDA: Learnable Knowledge-Guided Data Augmentation for Ev ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2106-01649: " LearnDA: Learnable Knowledge-G ... "
# WARNING Missing Expected Field 'booktitle' from entry zuo2021learnda: " LearnDA: Learnable knowledge-g ... "
# SUCESSFULLY PARSED DBLP:conf/cikm/Yang000W21: " Multi-Sentence Argument Linking via An Event-Aware Hierarchi ... "
# SUCESSFULLY PARSED DBLP:conf/cikm/Zhou00ZXJL21: " Multi-Task Self-Supervised Learning for Script Event Predict ... "
# SUCESSFULLY PARSED DBLP:conf/ccks/Huang00XS021: " {NSRL:} Named Entity Recognition with Noisy Labels via Selec ... "
# SUCESSFULLY PARSED DBLP:conf/acl/HuangCWZXS21: " Named Entity Recognition via Noise Aware Training Mechanism  ... "
# SUCESSFULLY PARSED DBLP:conf/eacl/ChenLCWZ21: " Probing into the Root: {A} Dataset for Reason Extraction of  ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/dint/LiGZCWLZL21: " Semi-Supervised Noisy Label Le ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/SuiW000B21: " Set Generation Networks for End-to-End Knowledge Base Popula ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/Cao0Y0021: " Uncertain Local-to-Global Networks for Document-Level Event  ... "
# SUCESSFULLY PARSED DBLP:conf/cikm/CaoZ00ZB21: " Uncertainty-Aware Self-Training for Semi-Supervised Event Te ... "
# SUCESSFULLY PARSED DBLP:conf/aaai/Zhou0ZWXL21: " What the Role is vs. What Plays the Role: Semi-Supervised Ev ... "
# SUCESSFULLY PARSED zhou2021role: " What the role is vs. what plays the role: Semi-supervised ev ... "
# SUCESSFULLY PARSED DBLP:conf/cncl/CaoCLZ20: " Chinese Named Entity Recognition via Adaptive Multi-pass Mem ... "
# SUCESSFULLY PARSED DBLP:conf/acl/CaoYFCLZLC20: " Clinical-Coder: Assigning Interpretable {ICD-10} Codes to Ch ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2008-05049: " Distantly Supervised Relation  ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2009-10290: " Event Coreference Resolution v ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/LiuCLBL20: " Event Extraction as Machine Reading Comprehension  "
# SUCESSFULLY PARSED liu2020event: " Event extraction as machine reading comprehension  "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/aiopen/LiuCLZZ20: " Extracting Events and Their Re ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/SuiCZJXS20: " FedED: Federated Learning via Ensemble Distillation for Medi ... "
# SUCESSFULLY PARSED sui2020feded: " Feded: Federated learning via ensemble distillation for medi ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/Liu00JS20: " How Does Context Matter? On the Robustness of Event Detectio ... "
# SUCESSFULLY PARSED DBLP:conf/acl/CaoCLZLC20: " HyperCore: Hyperbolic and Co-graph Representation for Automa ... "
# SUCESSFULLY PARSED cao2020hypercore: " HyperCore: Hyperbolic and co-graph representation for automa ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/CaoCZW20: " Incremental Event Detection via Knowledge Consolidation Netw ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2011-01675: " Joint Entity and Relation Extr ... "
# SUCESSFULLY PARSED DBLP:conf/coling/ZuoCLZ20: " KnowDis: Knowledge Enhanced Data Augmentation for Event Caus ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2010-10833: " KnowDis: Knowledge Enhanced Da ... "
# WARNING Missing Expected Field 'booktitle' from entry zuo2020knowdis: " KnowDis: Knowledge enhanced da ... "
# SUCESSFULLY PARSED DBLP:conf/ijcai/Liu0020: " Knowledge Enhanced Event Causality Identification with Menti ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2004-01907: " Knowledge Guided Metric Learni ... "
# SUCESSFULLY PARSED DBLP:conf/ccks/Yang00020: " Meta Learning for Event Argument Extraction via Domain-Speci ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2003-03875: " Overview of the {CCKS} 2019 Kn ... "
# SUCESSFULLY PARSED DBLP:conf/ijcnlp/ChenYLHCWZ20: " Reconstructing Event Regions for Event Extraction via Graph  ... "
# SUCESSFULLY PARSED DBLP:conf/cncl/ZuoCLZ20: " Towards Causal Explanation Detection with Pyramid Salient-Aw ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/corr/abs-2009-10288: " Towards Causal Explanation Det ... "
# SUCESSFULLY PARSED DBLP:conf/ccks/WangCLZ19: " Adaptive Multilingual Representations for Cross-Lingual Enti ... "
# SUCESSFULLY PARSED DBLP:conf/jist/ZhouCLZ19: " Attention-Based Direct Interaction Model for Knowledge Graph ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:journals/chinaf/ZuoCLZ19: " Event co-reference resolution  ... "
# SUCESSFULLY PARSED DBLP:conf/aaai/Liu0019: " Exploiting the Ground-Truth: An Adversarial Imitation Based  ... "
# SUCESSFULLY PARSED liu2019exploiting: " Exploiting the ground-truth: An adversarial imitation based  ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/SuiCLZL19: " Leverage Lexical Knowledge for Chinese Named Entity Recognit ... "
# SUCESSFULLY PARSED sui2019leverage: " Leverage lexical knowledge for Chinese named entity recognit ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/LiuCLZ19: " Neural Cross-Lingual Event Detection with Minimal Parallel R ... "
# SUCESSFULLY PARSED liu2019neural: " Neural cross-lingual event detection with minimal parallel r ... "
# SUCESSFULLY PARSED DBLP:conf/cncl/ZhouCLZ19: " Relation and Fact Type Supervised Knowledge Graph Embedding  ... "
# SUCESSFULLY PARSED DBLP:conf/ccks/Cao00018: " Adversarial Training for Relation Classification with Attent ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/Cao000L18: " Adversarial Transfer Learning for Chinese Named Entity Recog ... "
# SUCESSFULLY PARSED cao2018adversarial: " Adversarial transfer learning for Chinese named entity recog ... "
# SUCESSFULLY PARSED DBLP:conf/emnlp/0001Y00J18: " Collective Event Detection via a Hierarchical and Bias Taggi ... "
# SUCESSFULLY PARSED chen2018collective: " Collective event detection via a hierarchical and bias taggi ... "
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# e:\project\frontend_project\yubochen.github.io\markdown_generator\PubsFromBib.ipynb Cell 5 line 4
#      <a href='vscode-notebook-cell:/e%3A/project/frontend_project/yubochen.github.io/markdown_generator/PubsFromBib.ipynb#W4sZmlsZQ%3D%3D?line=44'>45</a> #citation authors - todo - add highlighting for primary author?
#      <a href='vscode-notebook-cell:/e%3A/project/frontend_project/yubochen.github.io/markdown_generator/PubsFromBib.ipynb#W4sZmlsZQ%3D%3D?line=45'>46</a> for author in bibdata.entries[bib_id].persons["author"]:
# ---> <a href='vscode-notebook-cell:/e%3A/project/frontend_project/yubochen.github.io/markdown_generator/PubsFromBib.ipynb#W4sZmlsZQ%3D%3D?line=46'>47</a>     citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "
#      <a href='vscode-notebook-cell:/e%3A/project/frontend_project/yubochen.github.io/markdown_generator/PubsFromBib.ipynb#W4sZmlsZQ%3D%3D?line=48'>49</a> #citation title
#      <a href='vscode-notebook-cell:/e%3A/project/frontend_project/yubochen.github.io/markdown_generator/PubsFromBib.ipynb#W4sZmlsZQ%3D%3D?line=49'>50</a> citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""
#
# IndexError: list index out of range
